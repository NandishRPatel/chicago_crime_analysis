# %% [markdown]
# Importing libraries needed

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Getting data into pandas dataframe

# %%
data_frame = pd.read_csv('chicago_crime_data.csv')

# %% [markdown]
# Taking sample from large dataframe

# %%
sample_dataframe = data_frame.sample(n=100000)

# %% [markdown]
# Selecting attributes manually

# %%
sample_dataframe = sample_dataframe[['ID', 'Case Number', 'Date', 'IUCR', 'Primary Type', 'Arrest', 'Domestic', 'Location']]

# %% [markdown]
# Cleaning data

# %%
sample_dataframne = sample_dataframe.dropna(inplace=True)

# %% [markdown]
# Simple bar graph showing types of crime and their frequency

# %%
types = sample_dataframe['Primary Type'].tolist()
types_list = list(set(types))
print(len(types_list))
x_axis = types_list
y_axis = []
for i in x_axis:
    y_axis.append(types.count(i))


plt.figure(figsize=(15, 9))
ax = plt.subplot(111)
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()
plt.xticks(range(len(x_axis)), x_axis,rotation='vertical')
plt.tick_params(axis='both',labelsize=15)
plt.xlabel("Types Of Crime", fontsize=18)
plt.ylabel("Number Of Crimes", fontsize=18)
plt.bar(x_axis, y_axis, align="center", alpha=0.5)
plt.suptitle('Crimes in Chicago', fontsize=20)
plt.show()
# Out:
# 30
